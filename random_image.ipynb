# %%
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib as cm
import numpy as np

# %%
randomarr = np.random.randint(0, 255, (300, 400)).astype(np.uint8)
Image.fromarray(randomarr)
# Out:
# <PIL.Image.Image image mode=L size=400x300 at 0x1143E1650>

# %%
randomarr = np.random.randint(0, 255, (300, 400, 3)).astype(np.uint8)
Image.fromarray(randomarr)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x113F9EDD0>
