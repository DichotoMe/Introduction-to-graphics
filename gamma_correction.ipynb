# %%
import math, numpy as np
import scipy.misc
from PIL import Image
import matplotlib.pyplot as plt

# %%
def gamma_correction(image, gamma):
    return np.asarray(255 * (image / 255) ** gamma).astype(np.uint8)

# %%
img = Image.open("images/chestxray.jpg")
plt.imshow(img, cmap='gray')

# %%
arr = gamma_correction(np.asarray(img), 0.5)

plt.imshow(Image.fromarray(arr), cmap='gray')

# %%
arr = gamma_correction(np.asarray(img), 2)

plt.imshow(Image.fromarray(arr), cmap='gray')

# %%
img = Image.open("images/pens.bmp")
plt.imshow(img, cmap='gray')

# %%
arr = gamma_correction(np.asarray(img), 0.5)

plt.imshow(Image.fromarray(arr), cmap='gray')

# %%
arr = gamma_correction(np.asarray(img), 2)

plt.imshow(Image.fromarray(arr), cmap='gray')
