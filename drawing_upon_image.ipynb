# %%
from PIL import Image
from pylab import *
# %matplotlib inline

# %%
arr = array(Image.open("images/pens.bmp"))

x = [100, 150, 300, 400]
y = [50, 20, 300, 100]

plot(x, y, "r*")

imshow(arr)

# %%
plot(x, y, "r")

imshow(arr)

# %%
plot(x, y, "c:")

imshow(arr)

# %%
title("I'd better do labs at KPI")

imshow(arr)

# %%
# Select 4 points by clicking

# %matplotlib tk
imshow(arr)

pts = ginput(4)

# %matplotlib inline

print("Selected", pts)
# Out:
# Selected [(239.1750977419612, 195.13073485996972), (107.04392404053297, 95.55361844729919), (89.80942312295534, 283.21818399425524), (105.12897949413545, 413.4344131492859)]
