# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def plotImage(image, cmap='gray'):
    try:
        plt.imshow(np.asarray(image), cmap=cmap, vmin=0, vmax=255)
    except:
        print("Error plotting the image", color='red')

# %%
# Read as array
arr = plt.imread('images/profile.jpg')

plt.imshow(arr)
arr, arr.shape, type(arr), arr.dtype
# Out:
# (array([[[123, 152, 156],
#          [124, 153, 157],
#          [125, 154, 158],
#          ...,
#          [225, 244, 250],
#          [226, 245, 251],
#          [226, 245, 251]],
#
#         [[123, 152, 156],
#          [124, 153, 157],
#          [125, 154, 158],
#          ...,
#          [226, 245, 251],
#          [226, 245, 251],
#          [227, 246, 252]],
#
#         [[123, 152, 156],
#          [124, 153, 157],
#          [125, 154, 158],
#          ...,
#          [227, 246, 252],
#          [228, 247, 253],
#          [228, 247, 253]],
#
#         ...,
#
#         [[130, 145, 152],
#          [129, 143, 152],
#          [129, 143, 152],
#          ...,
#          [251, 253, 204],
#          [251, 253, 204],
#          [251, 253, 204]],
#
#         [[130, 145, 152],
#          [129, 143, 152],
#          [129, 143, 152],
#          ...,
#          [251, 253, 204],
#          [251, 253, 204],
#          [251, 253, 204]],
#
#         [[129, 144, 151],
# ...
